# %%
# Importing Training CSV
import pandas as pd

df = pd.read_csv('C:\\Users\\yathg\\Desktop\\Actuarial Project 3\\train.csv')
df.head()
# Out:
#   ClaimNumber    DateTimeOfAccident          DateReported  Age Gender  \
# 0   WC8285054  2002-04-09T07:00:00Z  2002-07-05T00:00:00Z   48      M
# 1   WC6982224  1999-01-07T11:00:00Z  1999-01-20T00:00:00Z   43      F
# 2   WC5481426  1996-03-25T00:00:00Z  1996-04-14T00:00:00Z   30      M
# 3   WC9775968  2005-06-22T13:00:00Z  2005-07-22T00:00:00Z   41      M
# 4   WC2634037  1990-08-29T08:00:00Z  1990-09-27T00:00:00Z   36      M
#
#   MaritalStatus  DependentChildren  DependentsOther  WeeklyWages  \
# 0             M                  0                0       500.00
# 1             M                  0                0       509.34
# 2             U                  0                0       709.10
# 3             S                  0                0       555.46
# 4             M                  0                0       377.10
#
#   PartTimeFullTime  HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0                F                38.0                  5
# ...

# %%
# Checking for duplicates
duplicates = df[df.duplicated()]
print("Number of duplicate rows",len(duplicates))
duplicates
# Out:
# Number of duplicate rows 0
# Empty DataFrame
# Columns: [ClaimNumber, DateTimeOfAccident, DateReported, Age, Gender, MaritalStatus, DependentChildren, DependentsOther, WeeklyWages, PartTimeFullTime, HoursWorkedPerWeek, DaysWorkedPerWeek, ClaimDescription, InitialIncurredCalimsCost, UltimateIncurredClaimCost]
# Index: []

# %%
# Checking for missing values
df.isnull().sum()
df[df.isnull().any(axis=1)]
# Out:
#       ClaimNumber    DateTimeOfAccident          DateReported  Age Gender  \
# 1042    WC3603450  1992-09-25T14:00:00Z  1992-10-09T00:00:00Z   53      M
# 7587    WC3938584  1992-05-07T07:00:00Z  1992-05-23T00:00:00Z   58      F
# 7592    WC2469641  1989-10-09T09:00:00Z  1990-07-15T00:00:00Z   17      M
# 10482   WC9825722  2005-07-12T16:00:00Z  2005-10-27T00:00:00Z   42      M
# 10555   WC4853326  1994-02-10T22:00:00Z  1994-03-02T00:00:00Z   40      M
# 10761   WC3019033  1991-10-21T07:00:00Z  1991-10-29T00:00:00Z   33      M
# 12661   WC7426694  2000-10-17T15:00:00Z  2000-11-09T00:00:00Z   38      M
# 15203   WC3571601  1992-11-10T12:00:00Z  1992-11-26T00:00:00Z   47      F
# 15373   WC3926350  1992-07-10T11:00:00Z  1992-09-03T00:00:00Z   45      M
# 19783   WC8820716  2003-07-21T09:00:00Z  2003-07-28T00:00:00Z   18      F
# 21115   WC4258521  1993-12-10T17:00:00Z  1994-01-17T00:00:00Z   20      M
# 23321   WC9642440  2005-08-16T05:00:00Z  2005-10-28T00:00:00Z   30      M
# ...

# %%
#Filling the missing values
df = df.fillna('U')
#Assigning new data frame as original data frame
df.dropna(inplace=True)

# %%
#Rechecking for missing values
df.isnull().sum()
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ClaimNumber, DateTimeOfAccident, DateReported, Age, Gender, MaritalStatus, DependentChildren, DependentsOther, WeeklyWages, PartTimeFullTime, HoursWorkedPerWeek, DaysWorkedPerWeek, ClaimDescription, InitialIncurredCalimsCost, UltimateIncurredClaimCost]
# Index: []

# %%
#Checking statistics description & skewness
desc = df.describe()
desc.loc['skew'] = df.skew(numeric_only=True)
desc
# Out:
#                 Age  DependentChildren  DependentsOther   WeeklyWages  \
# count  54000.000000       54000.000000     54000.000000  54000.000000
# mean      33.842370           0.119185         0.009944    416.364807
# std       12.122165           0.517780         0.109348    248.638669
# min       13.000000           0.000000         0.000000      1.000000
# 25%       23.000000           0.000000         0.000000    200.000000
# 50%       32.000000           0.000000         0.000000    392.200000
# 75%       43.000000           0.000000         0.000000    500.000000
# max       81.000000           9.000000         5.000000   7497.000000
# skew       0.536341           5.112379        13.706834      4.122767
#
#        HoursWorkedPerWeek  DaysWorkedPerWeek  InitialIncurredCalimsCost  \
# count        54000.000000       54000.000000               5.400000e+04
# mean            37.735084           4.905759               7.841146e+03
# ...

# %%
# Differentiating right and left skewed columns
skewness = df.skew(numeric_only=True)
print("Right skewed columns:\n",skewness[skewness > 0.5])
print("Left skewed columns:\n",skewness[skewness < -0.5])
# Out:
# Right skewed columns:
#  Age                           0.536341
# DependentChildren             5.112379
# DependentsOther              13.706834
# WeeklyWages                   4.122767
# HoursWorkedPerWeek           24.132974
# InitialIncurredCalimsCost    26.853657
# UltimateIncurredClaimCost    37.552504
# dtype: float64
# Left skewed columns:
#  DaysWorkedPerWeek   -3.340468
# dtype: float64

# %%
import numpy as np

# Normalizing data - sqrt for right skewed but showing error when rechecking
df['WeeklyWages'] = np.sqrt(df['WeeklyWages'] + 1e-6)

#Special cases - Right skewed but had to do boxcox
df['DependentChildren'] = np.sqrt(df['DependentChildren'])
df['DependentsOther'] = np.sqrt(df['DependentsOther'])
df['HoursWorkedPerWeek'] = np.sqrt(df['HoursWorkedPerWeek'])

# log transform for right skewed
df['InitialIncurredCalimsCost'] = np.log1p(df['InitialIncurredCalimsCost'])
df['UltimateIncurredClaimCost'] = np.log1p(df['UltimateIncurredClaimCost'])

# Square root for left skewed
df['DaysWorkedPerWeek'] = np.sqrt(df['DaysWorkedPerWeek'].max() - df['DaysWorkedPerWeek'])

# %%
# Rechecking Skewness
skewness = df.skew(numeric_only=True)
print("Right skewed columns:\n",skewness[skewness > 0.5])
print("Left skewed columns:\n",skewness[skewness < -0.5])
# Out:
# Right skewed columns:
#  Age                    0.536341
# DependentChildren      3.995391
# DependentsOther       10.688563
# WeeklyWages            0.722194
# HoursWorkedPerWeek     3.076673
# dtype: float64
# Left skewed columns:
#  DaysWorkedPerWeek   -0.730092
# dtype: float64

# %%
# Extracting date from DateTimeofAccident and DateReported - 1
df['DateTimeOfAccident'] = pd.to_datetime(df['DateTimeOfAccident'], errors = 'coerce')
df['DateReported'] = pd.to_datetime(df['DateReported'], errors = 'coerce')

# %%
#Creating a useful column from dates - Reportdelay
df['Reportingdelay'] = df['DateReported'] - df['DateTimeOfAccident']
df['Reportingdelay'].head()
# Out:
# 0   86 days 17:00:00
# 1   12 days 13:00:00
# 2   20 days 00:00:00
# 3   29 days 11:00:00
# 4   28 days 16:00:00
# Name: Reportingdelay, dtype: timedelta64[ns]

# %%
#Converting Report delay days into integer type
df['ReportingDelayDays'] = df['Reportingdelay'].dt.days

# %%
#Dropping Date object columns
df.drop(['DateTimeOfAccident','DateReported'],axis = 1, inplace = True)

# %%
# Extracting hourly wages from weekly wages
df['HourlyWages'] = df['WeeklyWages']/df['HoursWorkedPerWeek']

# %%
# Creating Correlation Matrix to check collinearity between variables
import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix=df.corr(numeric_only=True)

plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
#Cleaning Texts
import pandas as pd
import re

def clean_text(text):
    text = text.strip()                           #Remove leading/trailing whitespace
    text = text.lower()                           #convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)           #Remove punctuation
    text = re.sub(r'\s+', ' ', text)              #Collapse multiple spaces
    return text

df['Gender'] = df['Gender'].apply(clean_text)
df['MaritalStatus'] = df['MaritalStatus'].apply(clean_text)
df['PartTimeFullTime'] = df['PartTimeFullTime'].apply(clean_text)

df.head()
# Out:
#   ClaimNumber  Age Gender MaritalStatus  DependentChildren  DependentsOther  \
# 0   WC8285054   48      m             m                0.0              0.0
# 1   WC6982224   43      f             m                0.0              0.0
# 2   WC5481426   30      m             u                0.0              0.0
# 3   WC9775968   41      m             s                0.0              0.0
# 4   WC2634037   36      m             m                0.0              0.0
#
#    WeeklyWages PartTimeFullTime  HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0    22.360680                f            6.164414           1.414214
# 1    22.568562                f            6.123724           1.414214
# 2    26.628932                f            6.164414           1.414214
# 3    23.568199                f            6.164414           1.414214
# 4    19.419063                f            6.164414           1.414214
#
#                                     ClaimDescription  \
# ...

# %%
# One hot encoding Gender, MaritalStatus, PartTimeFullTime
df = pd.get_dummies(df,columns=['Gender'],drop_first=True)
df = pd.get_dummies(df,columns = ['MaritalStatus'],drop_first=True)
df = pd.get_dummies(df,columns = ['PartTimeFullTime'],drop_first=True)

df.head()
# Out:
#   ClaimNumber  Age  DependentChildren  DependentsOther  WeeklyWages  \
# 0   WC8285054   48                0.0              0.0    22.360680
# 1   WC6982224   43                0.0              0.0    22.568562
# 2   WC5481426   30                0.0              0.0    26.628932
# 3   WC9775968   41                0.0              0.0    23.568199
# 4   WC2634037   36                0.0              0.0    19.419063
#
#    HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0            6.164414           1.414214
# 1            6.123724           1.414214
# 2            6.164414           1.414214
# 3            6.164414           1.414214
# 4            6.164414           1.414214
#
#                                     ClaimDescription  \
# 0  LIFTING TYRE INJURY TO RIGHT ARM AND WRIST INJURY
# 1  STEPPED AROUND CRATES AND TRUCK TRAY FRACTURE ...
# 2                   CUT ON SHARP EDGE CUT LEFT THUMB
# 3               DIGGING LOWER BACK LOWER BACK STRAIN
# ...

# %%
unique_gender = df['Gender_u'].unique()
print(unique_gender)
# Out:
# [False  True]

# %%
#Extracting body parts from Claim Description
import pandas as pd

# Example body parts to look for
body_parts = ['SHOULDER', 'KNEE', 'WRIST', 'ANKLE', 'BACK', 'LEG', 'ARM', 'HAND', 'FOOT', 'ELBOW', 'NECK', 'THUMB', 'HEAD', 'FINGER', 'EYE',
              'CHEST', 'CORNEA', 'LIP', 'CHEEK', 'HIP', 'FOREARM', 'CALF', 'RASH', 'HERNIA', 'TISSUE', 'TENDON', 'INDEX', 'INHALATION'
             'FOREHEAD', 'ACCIDENT','SKULL','FACE', 'EYELID', 'FRACTURE', 'ACID', 'WASP', 'EYES', 'TEETH', 'RIBS', 'GROIN', 'SCALP']

# Create a regex pattern from the list
pattern = r'\b(' + '|'.join(body_parts) + r')\b'

#Converting Column into string
df['ClaimDescription'] = df['ClaimDescription'].astype(str)

# Extract the first matching body part
df['BodyPart'] = df['ClaimDescription'].str.extract(pattern, expand=False)

# %%
# Replacing any missing body part with 'Other Disease'
#Filling the missing values
df = df.fillna('OtherD')
#Assigning new data frame as original data frame
df.dropna(inplace=True)

# %%
# Checking for missing values
df.isnull().sum()
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ClaimNumber, Age, DependentChildren, DependentsOther, WeeklyWages, HoursWorkedPerWeek, DaysWorkedPerWeek, ClaimDescription, InitialIncurredCalimsCost, UltimateIncurredClaimCost, Reportingdelay, ReportingDelayDays, HourlyWages, Gender_m, Gender_u, MaritalStatus_s, MaritalStatus_u, PartTimeFullTime_p, BodyPart]
# Index: []

# %%
#Extracting only the number from claim number
df['ClNumber'] = df['ClaimNumber'].astype(str).str.replace(',', '').str.extract(r'(\d+)', expand=False).astype(int)

print(df)
# Out:
#       ClaimNumber  Age  DependentChildren  DependentsOther  WeeklyWages  \
# 0       WC8285054   48                0.0              0.0    22.360680
# 1       WC6982224   43                0.0              0.0    22.568562
# 2       WC5481426   30                0.0              0.0    26.628932
# 3       WC9775968   41                0.0              0.0    23.568199
# 4       WC2634037   36                0.0              0.0    19.419063
# ...           ...  ...                ...              ...          ...
# 53995   WC9370727   32                0.0              0.0    22.360680
# 53996   WC8396269   20                0.0              0.0    22.360680
# 53997   WC3609528   19                0.0              0.0    16.822604
# 53998   WC5038565   24                0.0              0.0    14.142136
# 53999   WC2542601   22                0.0              0.0    14.142136
#
#        HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0                6.164414           1.414214
# ...

# %%
#Label encoding Body part column as Encoded Keyword
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['EncodedKeyword'] = le.fit_transform(df['BodyPart'])

# %%
# Dropping Claim Description and Body Part and Reporting delay
df.drop(['ClaimDescription', 'BodyPart', 'ClaimNumber', 'Reportingdelay'],axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age  DependentChildren  DependentsOther  WeeklyWages  HoursWorkedPerWeek  \
# 0   48                0.0              0.0    22.360680            6.164414
# 1   43                0.0              0.0    22.568562            6.123724
# 2   30                0.0              0.0    26.628932            6.164414
# 3   41                0.0              0.0    23.568199            6.164414
# 4   36                0.0              0.0    19.419063            6.164414
#
#    DaysWorkedPerWeek  InitialIncurredCalimsCost  UltimateIncurredClaimCost  \
# 0           1.414214                   7.313887                   8.465732
# 1           1.414214                   8.612685                   8.752627
# 2           1.414214                   7.438972                   7.738466
# 3           1.414214                   9.615872                   9.786251
# 4           1.414214                   7.937732                   8.297793
#
# ...

# %%
#Dropping Gender U (Female) as it is not present in our Y dataset
df.drop(['Gender_u'],axis=1, inplace=True)

# %%
# Training our ML model - XG Boost
X_train = df.drop('UltimateIncurredClaimCost', axis=1)
y_train = df['UltimateIncurredClaimCost']

# %%
import numpy as np

# Check for infinite values
print(np.isinf(X_train).sum().sum())
# Out:
# 29

# %%
X_train.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
X_train.fillna(X_train.mean(), inplace=True)

# %%
print(np.isinf(y_train).sum().sum())
# Out:
# 0

# %%
from xgboost import XGBRegressor
model = XGBRegressor(random_state=51)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=51, ...)

# %%
#Importing our test dataset
df1 = pd.read_csv('C:\\Users\\yathg\\Desktop\\Actuarial Project 3\\test.csv')
df1.head()
# Out:
#   ClaimNumber    DateTimeOfAccident          DateReported  Age Gender  \
# 0   WC8145235  2002-04-02T10:00:00Z  2002-05-07T00:00:00Z   26      M
# 1   WC2005111  1988-04-06T16:00:00Z  1988-04-15T00:00:00Z   31      M
# 2   WC6899143  1999-03-08T09:00:00Z  1999-04-04T00:00:00Z   57      M
# 3   WC5502023  1996-07-26T09:00:00Z  1996-09-04T00:00:00Z   33      M
# 4   WC4785156  1994-04-13T14:00:00Z  1994-07-07T00:00:00Z   32      F
#
#   MaritalStatus  DependentChildren  DependentsOther  WeeklyWages  \
# 0             S                  1                0       600.18
# 1             M                  0                0       311.54
# 2             M                  0                0      1000.00
# 3             M                  0                0       200.00
# 4             M                  0                0       359.60
#
#   PartTimeFullTime  HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0                F                40.0                  5
# ...

# %%
# Checking for duplicates in test
duplicates = df1[df1.duplicated()]
print("Number of duplicate rows",len(duplicates))
duplicates
# Out:
# Number of duplicate rows 0
# Empty DataFrame
# Columns: [ClaimNumber, DateTimeOfAccident, DateReported, Age, Gender, MaritalStatus, DependentChildren, DependentsOther, WeeklyWages, PartTimeFullTime, HoursWorkedPerWeek, DaysWorkedPerWeek, ClaimDescription, InitialIncurredCalimsCost]
# Index: []

# %%
# Checking for missing values in test
df1.isnull().sum()
df1[df1.isnull().any(axis=1)]
# Out:
#       ClaimNumber    DateTimeOfAccident          DateReported  Age Gender  \
# 4865    WC3211424  1991-08-27T14:00:00Z  1991-10-08T00:00:00Z   58      M
# 5725    WC9709823  2005-06-16T19:00:00Z  2005-07-12T00:00:00Z   34      M
# 6532    WC9770476  2005-04-11T15:00:00Z  2005-05-01T00:00:00Z   17      F
# 6938    WC2895828  1990-03-08T08:00:00Z  1990-03-17T00:00:00Z   18      M
# 7529    WC4228665  1993-06-03T12:00:00Z  1993-06-16T00:00:00Z   30      M
# 8856    WC4400678  1993-04-28T14:00:00Z  1993-06-18T00:00:00Z   19      M
# 10607   WC3247784  1991-02-22T08:00:00Z  1991-03-12T00:00:00Z   41      F
# 11383   WC3366340  1991-12-05T09:00:00Z  1992-01-11T00:00:00Z   31      M
# 11537   WC4047526  1993-05-19T12:00:00Z  1993-06-12T00:00:00Z   31      M
# 14508   WC4302661  1993-11-24T08:00:00Z  1993-12-30T00:00:00Z   20      F
# 17139   WC3549813  1992-02-19T17:00:00Z  1992-02-27T00:00:00Z   33      M
# 17939   WC7305113  2000-09-12T09:00:00Z  2001-09-21T00:00:00Z   47      M
# ...

# %%
#Filling the missing values in test
df1 = df1.fillna('U')
#Assigning new data frame as original data frame
df1.dropna(inplace=True)

# %%
#Rechecking for missing values in test
df1.isnull().sum()
df1[df1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ClaimNumber, DateTimeOfAccident, DateReported, Age, Gender, MaritalStatus, DependentChildren, DependentsOther, WeeklyWages, PartTimeFullTime, HoursWorkedPerWeek, DaysWorkedPerWeek, ClaimDescription, InitialIncurredCalimsCost]
# Index: []

# %%
#Normalizing data for df1 - need to convert ypred into exponential later
import numpy as np

# Normalizing data - sqrt for right skewed but showing error when rechecking
df1['WeeklyWages'] = np.sqrt(df1['WeeklyWages'] + 1e-6)

#Special cases - Right skewed but had to do boxcox
df1['DependentChildren'] = np.sqrt(df1['DependentChildren'])
df1['DependentsOther'] = np.sqrt(df1['DependentsOther'])
df1['HoursWorkedPerWeek'] = np.sqrt(df1['HoursWorkedPerWeek'])

# log transform for right skewed
df1['InitialIncurredCalimsCost'] = np.log1p(df1['InitialIncurredCalimsCost'])

# Square root for left skewed
df1['DaysWorkedPerWeek'] = np.sqrt(df1['DaysWorkedPerWeek'].max() - df1['DaysWorkedPerWeek'])

# %%
#Correcting Dates in our Test dataset
# Extracting date from DateTimeofAccident and DateReported - 1
df1['DateTimeOfAccident'] = pd.to_datetime(df1['DateTimeOfAccident'], errors = 'coerce')
df1['DateReported'] = pd.to_datetime(df1['DateReported'], errors = 'coerce')

# %%
#Creating a useful column from dates - Reportdelay
df1['Reportingdelay'] = df1['DateReported'] - df1['DateTimeOfAccident']
df1['Reportingdelay'].head()
# Out:
# 0   34 days 14:00:00
# 1    8 days 08:00:00
# 2   26 days 15:00:00
# 3   39 days 15:00:00
# 4   84 days 10:00:00
# Name: Reportingdelay, dtype: timedelta64[ns]

# %%
#Converting Report delay days into integer type
df1['ReportingDelayDays'] = df1['Reportingdelay'].dt.days

# %%
#Dropping Date object columns
df1.drop(['DateTimeOfAccident','DateReported'],axis = 1, inplace = True)

# %%
# Extracting hourly wages from weekly wages in test
df1['HourlyWages'] = df1['WeeklyWages']/df1['HoursWorkedPerWeek']

# %%
#Cleaning Texts in test
import pandas as pd
import re

def clean_text(text):
    text = text.strip()                           #Remove leading/trailing whitespace
    text = text.lower()                           #convert to lowercase
    text = re.sub(r'[^\w\s]', '', text)           #Remove punctuation
    text = re.sub(r'\s+', ' ', text)              #Collapse multiple spaces
    return text

df1['ClaimDescription'] = df1['ClaimDescription'].apply(clean_text)
df1['Gender'] = df1['Gender'].apply(clean_text)
df1['MaritalStatus'] = df1['MaritalStatus'].apply(clean_text)
df1['PartTimeFullTime'] = df1['PartTimeFullTime'].apply(clean_text)

df1.head()
# Out:
#   ClaimNumber  Age Gender MaritalStatus  DependentChildren  DependentsOther  \
# 0   WC8145235   26      m             s                1.0              0.0
# 1   WC2005111   31      m             m                0.0              0.0
# 2   WC6899143   57      m             m                0.0              0.0
# 3   WC5502023   33      m             m                0.0              0.0
# 4   WC4785156   32      f             m                0.0              0.0
#
#    WeeklyWages PartTimeFullTime  HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0     4.949603                f            2.514867           1.414214
# 1     4.201249                f            2.432299           1.414214
# 2     5.623413                f            2.482824           1.414214
# 3     3.760603                f            2.482824           1.414214
# 4     4.354667                f            2.514867           1.414214
#
#                                     ClaimDescription  \
# ...

# %%
# One hot encoding Gender, MaritalStatus, PartTimeFullTime
df1 = pd.get_dummies(df1,columns=['Gender'],drop_first=True)
df1 = pd.get_dummies(df1,columns = ['MaritalStatus'],drop_first=True)
df1 = pd.get_dummies(df1,columns=['PartTimeFullTime'],drop_first=True)

df1.head()
# Out:
#   ClaimNumber  Age  DependentChildren  DependentsOther  WeeklyWages  \
# 0   WC8145235   26                1.0              0.0     4.949603
# 1   WC2005111   31                0.0              0.0     4.201249
# 2   WC6899143   57                0.0              0.0     5.623413
# 3   WC5502023   33                0.0              0.0     3.760603
# 4   WC4785156   32                0.0              0.0     4.354667
#
#    HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0            2.514867           1.414214
# 1            2.432299           1.414214
# 2            2.482824           1.414214
# 3            2.482824           1.414214
# 4            2.514867           1.414214
#
#                                     ClaimDescription  \
# 0   caught right hand with hammer burn to right hand
# 1          sprained right ankle fracture right elbow
# 2            struck hammer crush injury fingers hand
# 3  struck against air hose struck glass laceratio...
# ...

# %%
#Extracting body parts from Claim Description
import pandas as pd

# Example body parts to look for
body_parts = ['SHOULDER', 'KNEE', 'WRIST', 'ANKLE', 'BACK', 'LEG', 'ARM', 'HAND', 'FOOT', 'ELBOW', 'NECK', 'THUMB', 'HEAD', 'FINGER', 'EYE',
              'CHEST', 'CORNEA', 'LIP', 'CHEEK', 'HIP', 'FOREARM', 'CALF', 'RASH', 'HERNIA', 'TISSUE', 'TENDON', 'INDEX', 'INHALATION'
             'FOREHEAD', 'ACCIDENT','SKULL','FACE', 'EYELID', 'FRACTURE', 'ACID', 'WASP', 'EYES', 'TEETH', 'RIBS', 'GROIN', 'SCALP']

# Create a regex pattern from the list
pattern = r'\b(' + '|'.join(body_parts) + r')\b'

#Converting Column into string
df1['ClaimDescription'] = df1['ClaimDescription'].astype(str)

# Extract the first matching body part
df1['BodyPart'] = df1['ClaimDescription'].str.extract(pattern, expand=False)

# %%
# Replacing any missing body part with 'Other Disease'
#Filling the missing values
df1 = df1.fillna('OtherD')
#Assigning new data frame as original data frame
df1.dropna(inplace=True)

# %%
# Checking for missing values
df1.isnull().sum()
df1[df1.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ClaimNumber, Age, DependentChildren, DependentsOther, WeeklyWages, HoursWorkedPerWeek, DaysWorkedPerWeek, ClaimDescription, InitialIncurredCalimsCost, Reportingdelay, ReportingDelayDays, HourlyWages, Gender_m, MaritalStatus_s, MaritalStatus_u, PartTimeFullTime_p, BodyPart]
# Index: []

# %%
#Extracting only the number from claim number
df1['ClNumber'] = df1['ClaimNumber'].astype(str).str.replace(',', '').str.extract(r'(\d+)', expand=False).astype(int)

print(df1)
# Out:
#       ClaimNumber  Age  DependentChildren  DependentsOther  WeeklyWages  \
# 0       WC8145235   26                1.0              0.0     4.949603
# 1       WC2005111   31                0.0              0.0     4.201249
# 2       WC6899143   57                0.0              0.0     5.623413
# 3       WC5502023   33                0.0              0.0     3.760603
# 4       WC4785156   32                0.0              0.0     4.354667
# ...           ...  ...                ...              ...          ...
# 35995   WC9666858   54                0.0              0.0     5.213387
# 35996   WC4800526   22                0.0              0.0     4.649422
# 35997   WC3360567   35                0.0              0.0     3.578855
# 35998   WC7491778   45                0.0              0.0     3.760603
# 35999   WC5368443   63                0.0              0.0     3.760603
#
#        HoursWorkedPerWeek  DaysWorkedPerWeek  \
# 0                2.514867           1.414214
# ...

# %%
#Label encoding Body part column as Encoded Keyword
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1['EncodedKeyword'] = le.fit_transform(df1['BodyPart'])

# %%
# Dropping Claim Description and Body Part and Reporting delay
df1.drop(['ClaimDescription', 'BodyPart', 'ClaimNumber', 'Reportingdelay'],axis=1, inplace=True)

# %%
df1.head()
# Out:
#    Age  DependentChildren  DependentsOther  WeeklyWages  HoursWorkedPerWeek  \
# 0   26                1.0              0.0     4.949603            2.514867
# 1   31                0.0              0.0     4.201249            2.432299
# 2   57                0.0              0.0     5.623413            2.482824
# 3   33                0.0              0.0     3.760603            2.482824
# 4   32                0.0              0.0     4.354667            2.514867
#
#    DaysWorkedPerWeek  InitialIncurredCalimsCost  ReportingDelayDays  \
# 0           1.414214                   2.259223                  34
# 1           1.414214                   2.151925                   8
# 2           1.414214                   2.389087                  26
# 3           1.414214                   1.925822                  39
# 4           1.414214                   2.197969                  84
#
#    HourlyWages  Gender_m  MaritalStatus_s  MaritalStatus_u  \
# ...

# %%
#Applying our ML model our test
X_test = df1[X_train.columns]
y_pred = model.predict(X_test)

# %%
y_pred = np.expm1(y_pred)

# %%
y_pred_series = pd.Series(y_pred, name='Predictedvalues')

# %%
X_test = X_test.reset_index(drop=True)
y_pred_series = y_pred_series.reset_index(drop=True)

# %%
df_results = pd.concat([X_test, y_pred_series], axis=1)

# %%
df_results.to_csv('test_with_predictions.csv', index=False)
